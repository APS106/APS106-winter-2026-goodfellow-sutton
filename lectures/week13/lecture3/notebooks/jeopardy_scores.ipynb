# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 13 | Lecture 3 (13.3) - Jeopardy

# %%
import utils

# %%
scores = {
    'mechanical': sum([]),
    'chemical': sum([500, 500, -1000, 500, -1000, -1000, -1000, -1000, 500, 1000]),
    'civil': sum([1000, 1000, 250]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([]),
    'track1': sum([1000, -500, 500, 250, 1000, -1000, 1000, 1000])
}

utils.plot_scores(scores)
