# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 9 | Lecture 3 (9.3) - Term Test 2 Jeopardy Review

# %%
import utils

# %%
scores = {
    'mechanical': sum([1000]),
    'chemical': sum([1000, 500, 500, 500, 250]),
    'civil': sum([1000, 1000, 250, 250, -250]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([]),
    'track1': sum([-1000, 500, -1000, -250, 250])
}

utils.plot_scores(scores)
