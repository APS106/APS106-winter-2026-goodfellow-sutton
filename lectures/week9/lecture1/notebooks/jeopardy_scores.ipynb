# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 9 | Lecture 1 (9.1) - Term Test 2 Jeopardy Review

# %%
import utils

# %%
scores = {
    'Mechanical': sum([]),
    'Chemical': sum([-500,1000,-750,250,-750,-750, 750,1000, 250, 1000]),
    'Civil': sum([500, -750,1000,-750, 250, -1000, -500, 500]),
    'Mineral': sum([]),
    'Materials': sum([]),
    'Industrial': sum([-1000,-750, 750,-1000, 4000]),
    'Track1': sum([])
}

utils.plot_scores(scores)

# %%
def filter_and_organize_books(book_list, min_price):

    dictionary={}

    for book_tuple in book_list:

        title, author, price, genre = book_tuple

        if price >= min_price:

            if genre in dictionary.keys():
                dictionary[genre].append(title)
            else:
                dictionary[genre] = [title]

    return dictionary
