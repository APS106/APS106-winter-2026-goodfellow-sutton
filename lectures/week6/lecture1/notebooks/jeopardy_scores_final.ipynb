# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 12 | Lecture 1 (12.1) - Jeopardy Review

# %%
import utils

# %%
scores = {
    'mechanical': sum([400,600]),
    'chem': sum([1000,-1000, -800, 200, 1000]),
    'civil': sum([-400, 300, 400, 800, -600, -600, 800, 1000, 800, 400, -200, 3000]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([-800]),
    'track1': sum([])
}

utils.plot_scores(scores)

# %%
class LibraryEmployee:

    def __init__(self, name, books):
        self.name = name
        self.books= books
        self.num_coffees = 0

    def drink_coffee(self,num):
        self.num_coffees += num

    def shush_hooligans(self,num_hooligans):
        for i in range(num_hooligans):
            print("Shhh!")
            self.drink_coffee(1)

    def __str__(self):
        return f"Name: {self.name}, Books: {self.books}, Num_coffees: {self.num_coffees}"
