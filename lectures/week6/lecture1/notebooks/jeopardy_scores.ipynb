# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 6 | Lecture 1 (6.1) - Jeopardy Review

# %%
import utils

# %%
scores = {
    'mechanical': sum([1000]),
    'chem': sum([250, 250,-1000, -250, -250, -250, -750, 750, -1000, 3500]),
    'civil': sum([-1000, 500, -250, 500, -750, 1000]),
    'mineral': sum([0]),
    'materials': sum([0]),
    'industrial': sum([1000, 250, -250, 250, -750]),
    'track1': sum([0])
}

utils.plot_scores(scores)

# %%
def check_command(command_string):
    if command_string.startswith("CMD"):
        i = 0
        count = 0
        while i < len(command_string):
            if command_string[i].isnumeric():
                count += 1
            i += 1
        result = "valid"
    else:
        result = "invalid"
    return result

test_string= "CMD:1234Y6"
result = check_command(test_string)

file = open("data_logged.txt", "a")
file.write(test_string+","+result+"\n")
file.close()
